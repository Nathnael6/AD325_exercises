# %% [markdown]
#  Weekly Exercises 7 - Priority Queues and Heaps
#  Nathnael Yirga
#  AD325 - Data Structures & Algorithms
# week 7

# %% [markdown]
#  Part 1: DataLemur - Looping Number
#
# This section contains my solution to the DataLemur problem Looping Number.

# %% [markdown]
# Part 2: LeetCode - Relative Ranks (Heap Solution)
#
# This section contains my heap-based solution for the LeetCode problem Relative Ranks.
